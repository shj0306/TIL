# %% [markdown]
# ## keras image application - Ensemble 학습

# %%
from tensorflow.keras.applications.vgg16 import VGG16, decode_predictions
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet import ResNet101

# %%
from google.colab import files
up = files.upload()
# Out:
#      <input type="file" id="files-14380d10-96a8-41c7-8f09-7278604d0928" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-14380d10-96a8-41c7-8f09-7278604d0928">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving animals.zip to animals.zip

# %%
# !unzip animals.zip -d animals > /dev/null

# %%
up = files.upload()
# Out:
#      <input type="file" id="files-b63cba0b-1dd3-4e4c-a58c-e5879d93f53c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b63cba0b-1dd3-4e4c-a58c-e5879d93f53c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving image_util.py to image_util.py

# %%
from PIL import Image
import os
import matplotlib.pyplot as plt

# %%
animal_dir = '/content/animals/'

animals = os.listdir('/content/animals/')
img_path = animal_dir+animals[1]
img = Image.open(img_path)
plt.imshow(img);

# %%
vgg16 = VGG16()
vgg19 = VGG19()
resnet50 = ResNet50()
resnet101 = ResNet101()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467904/553467096 [==============================] - 3s 0us/step
# 553476096/553467096 [==============================] - 3s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels.h5
# 574717952/574710816 [==============================] - 3s 0us/step
# 574726144/574710816 [==============================] - 3s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels.h5
# 102973440/102967424 [==============================] - 1s 0us/step
# 102981632/102967424 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101_weights_tf_dim_ordering_tf_kernels.h5
# 179650560/179648224 [==============================] - 1s 0us/step
# 179658752/179648224 [==============================] - 1s 0us/step

# %% [markdown]
# - 이미지 예측

# %%
import numpy as np
from glob import glob
from image_util import center_image

# %%
lines = []

for fname in glob('animals/*.jpg'):
    name = fname.split('/')[1].split('.')[0]
    img = center_image(Image.open(fname), src_format='Pillow')
    yhat_v16 = vgg16.predict(img.reshape(1,224,224,3))
    yhat_v19 = vgg19.predict(img.reshape(1,224,224,3))
    yhat_r50 = resnet50.predict(img.reshape(1,224,224,3))
    yhat_r101 = resnet101.predict(img.reshape(1,224,224,3))

    yhat_ens = (yhat_v16 + yhat_v19 + yhat_r50 + yhat_r101) / 4.

    pred_v16 = decode_predictions(yhat_v16)[0][0][1]
    pred_v19 = decode_predictions(yhat_v19)[0][0][1]
    pred_r50 = decode_predictions(yhat_r50)[0][0][1]
    pred_r101 = decode_predictions(yhat_r101)[0][0][1]
    pred_ens = decode_predictions(yhat_ens)[0][0][1]

    lines.append([name, pred_v16, pred_v19, pred_r50, pred_r101, pred_ens])
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 40960/35363 [==================================] - 0s 0us/step
# 49152/35363 [=========================================] - 0s 0us/step

# %% [markdown]
# - 결과 확인

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,5))

for i, fname in enumerate(glob('animals/*.jpg')):
    plt.subplot(2,5,i+1)
    plt.imshow(center_image(Image.open(fname),
                            src_format='Pillow', dst_format='Pillow'))
    plt.title(fname.split('/')[1].split('.')[0])
    plt.axis('off')

plt.show()

# %%
df = pd.DataFrame(lines,
                  columns=['Name', 'VGG16', 'VGG19', 'ResNet50', 'ResNet101', 'Ensemble'])

# %%
df
# Out:
#         Name              VGG16               VGG19            ResNet50  \
# 0       lion               lion                lion                lion
# 1      eagle               kite                kite                kite
# 2      shark  great_white_shark   great_white_shark   great_white_shark
# 3    sparrow              quail                 jay           chickadee
# 4  crocodile              agama  American_alligator  American_alligator
# 5   elephant   African_elephant    African_elephant    African_elephant
# 6    dolphin             dugong          hammerhead          hammerhead
# 7       bear         brown_bear            ice_bear            ice_bear
# 8       hawk               kite                kite               screw
# 9    penguin       king_penguin        king_penguin        king_penguin
#
#             ResNet101            Ensemble
# 0                lion                lion
# 1                kite                kite
# 2   great_white_shark   great_white_shark
# 3                 jay                 jay
# 4  American_alligator  American_alligator
# 5    African_elephant    African_elephant
# 6          hammerhead          hammerhead
# 7          brown_bear            ice_bear
# 8                kite                kite
# 9        king_penguin        king_penguin
