# %%
# %cd /content/drive/MyDrive/multi/0525
# Out:
# /content/drive/MyDrive/multi/0525

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
from tensorflow.keras.applications.vgg16 import VGG16, decode_predictions

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from google.colab import files

# %%
up = files.upload()
# Out:
#      <input type="file" id="files-d13e0ac9-3036-411a-b194-84282fc969bc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d13e0ac9-3036-411a-b194-84282fc969bc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 개.jpg to 개.jpg
# Saving 개1.jfif to 개1.jfif
# Saving 개2.jpg to 개2.jpg
# Saving 고양이.jpg to 고양이.jpg
# Saving 고양이1.jpg to 고양이1.jpg
# Saving 고양이2.jfif to 고양이2.jfif

# %%
img = Image.open('고양이.jpg')
plt.imshow(img);

# %%
img = img.resize((224,224))
plt.imshow(img);

# %% [markdown]
# - 이미지 예측

# %%
vgg16 = VGG16(input_shape=(224,224,3))

# %% [markdown]
# ## ResNet 응용

# %%
from tensorflow.keras.applications.resnet50 import ResNet50, decode_predictions

# %%
resnet50 = ResNet50()
resnet50.summary()

# %%
img = Image.open('개.jpg')
img = center_image(img, src_format='Pillow', dst_format='Pillow')
plt.imshow(img);

# %%
yhat = resnet50.predict(np.array(img).reshape(1,224,244,3))
label = decode_predictions(yhat)
label
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-341e16be4ee7> in <module>()
# ----> 1 yhat = resnet50.predict(np.array(img).reshape(1,224,244,3))
#       2 label = decode_predictions(yhat)
#       3 label
#
# ValueError: cannot reshape array of size 817920 into shape (1,224,244,3)
